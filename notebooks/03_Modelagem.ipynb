# %% [markdown]
# # 03 — Modelagem
#
# **Issues #7–#10** · Milestone M3
#
# - Classificação: LR, Random Forest, SVM (#7)
# - Regressão: `money_diff` (#8)
# - KNN (#9)
# - ROC, matriz de confusão, feature importance (#10)

# %%
from pathlib import Path

METRICS = Path("/content/reports/metrics")
FIGURES = Path("/content/reports/figures")
METRICS.mkdir(parents=True, exist_ok=True)
FIGURES.mkdir(parents=True, exist_ok=True)

print("Notebook stub — implementar nas branches issue-7 a issue-10")
