# %% [markdown]
# # 02 — Pré-processamento
#
# **Issues #5 e #6** · Milestone M2
#
# ## Regras
# - `time_left >= 150`, 5v5, excluir `de_cache`
# - Features: `money_diff`, buy tier, AWP, rifles, util
# - Pipeline: `StandardScaler` + `OneHotEncoder` + split estratificado

# %%
import json
from pathlib import Path

import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

DATA_PROCESSED = Path("/content/data/processed")
DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

# TODO issue #5: filter_round_start + add_derived_features (portar do protótipo)
print("Notebook stub — implementar nas branches issue-5 e issue-6")
